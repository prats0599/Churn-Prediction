# %%
# Artifical Neural Networks

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, -1].values
# Encoding categorical data 
# Encoding the Independent Variable

# v0.20
#from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#labelencoder_X1 = LabelEncoder()
#X[:, 1] = labelencoder_X1.fit_transform(X[:, 1])
#labelencoder_X2 = LabelEncoder()
#X[:, 2] = labelencoder_X2.fit_transform(X[:, 2])
#onehotencoder = OneHotEncoder(categorical_features = [1])
#X = onehotencoder.fit_transform(X).toarray()
#X = X[:, 1:]
        
# v0.22
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("Country", OneHotEncoder(), [1, 2])], remainder = 'passthrough')
X = ct.fit_transform(X)
X = pd.DataFrame(X)
X = X.iloc[:, 1:].values
X = X[:, [0, 1, 3, 4, 5, 6, 7, 8, 9, 10, 11]]

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# making ANN

# Importing the keras libraries
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initializing the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
# relu--> rectifier activation function https://www.google.com/url?sa=i&source=images&cd=&cad=rja&uact=8&ved=2ahUKEwi7h9OC7NDmAhUl4XMBHRc_A5AQjRx6BAgBEAQ&url=%2Furl%3Fsa%3Di%26source%3Dimages%26cd%3D%26ved%3D2ahUKEwiy_4eB7NDmAhX083MBHUt9C6cQjRx6BAgBEAQ%26url%3Dhttps%253A%252F%252Fmedium.com%252F%2540kanchansarkar%252Frelu-not-a-differentiable-function-why-used-in-gradient-based-optimization-7fef3a4cecec%26psig%3DAOvVaw1OS0b2vQnWTxM5CFcbulZQ%26ust%3D1577364819708851&psig=AOvVaw1OS0b2vQnWTxM5CFcbulZQ&ust=1577364819708851
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
# softmax is a sigmoid function applied to a dependant variable that has more than 2 categories. for 2 categories use activation = 'sigmoid'
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Making predictions and evaluating model 
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Predicting single observation
"""Geography: France
Credit Score: 600
Gender: Male
Age: 40 years old
Tenure: 3 years
Balance: $60000
Number of Products: 2
Does this customer have a credit card ? Yes
Is this customer an Active Member: Yes
Estimated Salary: $50000 """
new_prediction = classifier.predict(sc.transform(np.array([[0, 0, 1, 600, 40, 3, 60000, 2, 1, 1, 50000]])))
new_prediction = (new_prediction > 0.5)


# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)


# Evaluating the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

classifier = KerasClassifier(build_fn = build_classifier, batch_size = 10, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10, n_jobs = -1)
print(accuracies)
# Improving the Ann

# Tuning the ANN
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Epoch 1/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.4861 - accuracy: 0.7950
# Epoch 2/100
# 8000/8000 [==============================] - 1s 75us/step - loss: 0.4297 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.4241 - accuracy: 0.8019
# Epoch 4/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.4173 - accuracy: 0.8280
# Epoch 5/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.4127 - accuracy: 0.8306
# Epoch 6/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.4085 - accuracy: 0.8325
# Epoch 7/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.4056 - accuracy: 0.8345
# Epoch 8/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.4041 - accuracy: 0.8339
# Epoch 9/100
# 8000/8000 [==============================] - 1s 75us/step - loss: 0.4022 - accuracy: 0.8341
# Epoch 10/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.4009 - accuracy: 0.8367
# Epoch 11/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3998 - accuracy: 0.8335
# Epoch 12/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3993 - accuracy: 0.8340
# Epoch 13/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3986 - accuracy: 0.8350
# Epoch 14/100
# 8000/8000 [==============================] - 1s 75us/step - loss: 0.3977 - accuracy: 0.8356
# Epoch 15/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.3976 - accuracy: 0.8354
# Epoch 16/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.3971 - accuracy: 0.8332
# Epoch 17/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3969 - accuracy: 0.8339
# Epoch 18/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3968 - accuracy: 0.8340
# Epoch 19/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3963 - accuracy: 0.8340
# Epoch 20/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3962 - accuracy: 0.8344
# Epoch 21/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3962 - accuracy: 0.8338
# Epoch 22/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.3958 - accuracy: 0.8326
# Epoch 23/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3956 - accuracy: 0.8335
# Epoch 24/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3952 - accuracy: 0.8353
# Epoch 25/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3954 - accuracy: 0.8331
# Epoch 26/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3950 - accuracy: 0.8340
# Epoch 27/100
# 8000/8000 [==============================] - 1s 85us/step - loss: 0.3948 - accuracy: 0.8355
# Epoch 28/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3949 - accuracy: 0.8351
# Epoch 29/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3946 - accuracy: 0.8349
# Epoch 30/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3937 - accuracy: 0.8350
# Epoch 31/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3931 - accuracy: 0.8359
# Epoch 32/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3908 - accuracy: 0.8359
# Epoch 33/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3900 - accuracy: 0.8369
# Epoch 34/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3866 - accuracy: 0.8396
# Epoch 35/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3831 - accuracy: 0.8393
# Epoch 36/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3802 - accuracy: 0.8391
# Epoch 37/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3783 - accuracy: 0.8399
# Epoch 38/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3778 - accuracy: 0.8394
# Epoch 39/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3766 - accuracy: 0.8391
# Epoch 40/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3765 - accuracy: 0.8404
# Epoch 41/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3755 - accuracy: 0.8406
# Epoch 42/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3749 - accuracy: 0.8391
# Epoch 43/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3749 - accuracy: 0.8404
# Epoch 44/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3737 - accuracy: 0.8404
# Epoch 45/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3737 - accuracy: 0.8411
# Epoch 46/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3730 - accuracy: 0.8411
# Epoch 47/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3717 - accuracy: 0.8422
# Epoch 48/100
# 8000/8000 [==============================] - 1s 70us/step - loss: 0.3711 - accuracy: 0.8415
# Epoch 49/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3708 - accuracy: 0.8401
# Epoch 50/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3708 - accuracy: 0.8420
# Epoch 51/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3702 - accuracy: 0.8414
# Epoch 52/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3699 - accuracy: 0.8424
# Epoch 53/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3695 - accuracy: 0.8405
# Epoch 54/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3691 - accuracy: 0.8440
# Epoch 55/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3686 - accuracy: 0.8456
# Epoch 56/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3691 - accuracy: 0.8436
# Epoch 57/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3693 - accuracy: 0.8415
# Epoch 58/100
# 8000/8000 [==============================] - 1s 70us/step - loss: 0.3690 - accuracy: 0.8400
# Epoch 59/100
# 8000/8000 [==============================] - 1s 70us/step - loss: 0.3688 - accuracy: 0.8434
# Epoch 60/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3683 - accuracy: 0.8418
# Epoch 61/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3685 - accuracy: 0.8431
# Epoch 62/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3680 - accuracy: 0.8422
# Epoch 63/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3681 - accuracy: 0.8409
# Epoch 64/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3675 - accuracy: 0.8447
# Epoch 65/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.3672 - accuracy: 0.8432
# Epoch 66/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3677 - accuracy: 0.8416
# Epoch 67/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3676 - accuracy: 0.8436
# Epoch 68/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3675 - accuracy: 0.8426
# Epoch 69/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3676 - accuracy: 0.8421
# Epoch 70/100
# 8000/8000 [==============================] - 1s 71us/step - loss: 0.3668 - accuracy: 0.8419
# Epoch 71/100
# 8000/8000 [==============================] - 1s 70us/step - loss: 0.3682 - accuracy: 0.8426
# Epoch 72/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3672 - accuracy: 0.8426
# Epoch 73/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3669 - accuracy: 0.8446
# Epoch 74/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3669 - accuracy: 0.8435
# Epoch 75/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3672 - accuracy: 0.8440
# Epoch 76/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3674 - accuracy: 0.8416
# Epoch 77/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3669 - accuracy: 0.8416
# Epoch 78/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3664 - accuracy: 0.8431
# Epoch 79/100
# 8000/8000 [==============================] - 1s 89us/step - loss: 0.3664 - accuracy: 0.8429
# Epoch 80/100
# 8000/8000 [==============================] - 1s 75us/step - loss: 0.3665 - accuracy: 0.8439
# Epoch 81/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3668 - accuracy: 0.8424
# Epoch 82/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3666 - accuracy: 0.8436
# Epoch 83/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3666 - accuracy: 0.8407
# Epoch 84/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3668 - accuracy: 0.8435
# Epoch 85/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3665 - accuracy: 0.8431
# Epoch 86/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3662 - accuracy: 0.8460
# Epoch 87/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3664 - accuracy: 0.8422
# Epoch 88/100
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.3661 - accuracy: 0.8441
# Epoch 89/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3662 - accuracy: 0.8445
# Epoch 90/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3665 - accuracy: 0.8428
# Epoch 91/100
# 8000/8000 [==============================] - 1s 85us/step - loss: 0.3663 - accuracy: 0.8444
# Epoch 92/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3664 - accuracy: 0.8451
# Epoch 93/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3657 - accuracy: 0.8447
# Epoch 94/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3659 - accuracy: 0.8453
# Epoch 95/100
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.3662 - accuracy: 0.8450
# Epoch 96/100
# 8000/8000 [==============================] - 1s 73us/step - loss: 0.3660 - accuracy: 0.8431
# Epoch 97/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.3656 - accuracy: 0.8434
# Epoch 98/100
# 8000/8000 [==============================] - 1s 76us/step - loss: 0.3653 - accuracy: 0.8419
# Epoch 99/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3656 - accuracy: 0.8443
# Epoch 100/100
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.3663 - accuracy: 0.8436
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [0.84125    0.83375001 0.83749998 0.82875001 0.87       0.86000001
#  0.86374998 0.85124999 0.8125     0.83625001]
